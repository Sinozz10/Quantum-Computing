# %%
# !pip install qiskit
# Out:
# ...
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/7.2 MB 3.0 MB/s eta 0:00:03
#    -------- ------------------------------- 1.6/7.2 MB 3.0 MB/s eta 0:00:02
#    ------------- -------------------------- 2.4/7.2 MB 3.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.1/7.2 MB 3.4 MB/s eta 0:00:02
#    --------------------- ------------------ 3.9/7.2 MB 3.5 MB/s eta 0:00:01
#    --------------------------- ------------ 5.0/7.2 MB 3.6 MB/s eta 0:00:01
#    -------------------------------- ------- 5.8/7.2 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 6.6/7.2 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 3.5 MB/s  0:00:02
# ...

# %%
# !pip install qiskit-aer
# Out:
# ...
#   Using cached qiskit_aer-0.17.1-cp39-cp39-win_amd64.whl.metadata (8.5 kB)
# ...
# Using cached qiskit_aer-0.17.1-cp39-cp39-win_amd64.whl (9.5 MB)
# ...

# %%
# !pip install qiskit[visualization]
